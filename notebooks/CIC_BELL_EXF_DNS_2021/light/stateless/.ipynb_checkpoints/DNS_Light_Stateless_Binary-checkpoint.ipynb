# %% [markdown]
# # Citation
#
# Samaneh Mahdavifar, Amgad Hanafy Salem, Princy Victor, Miguel Garzon, Amir H. Razavi, Natasha Hellberg, Arash Habibi Lashkari, “Lightweight Hybrid Detection of Data Exfiltration using DNS based on Machine Learning”, The 11th IEEE International Conference on Communication and Network Security (ICCNS), Dec. 3-5, 2021, Beijing Jiaotong University, Weihai, China.

# %%
import re
import pandas as pd
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
import xgboost as xgb
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Load light stateless DNS data

# %% [markdown]
# Load each csv file into a corresponding dataframe*
#
# * Light stateless data has 3 benign csv files that will be concatenated into a single dataframe

# %%
stateless_light_audio = pd.read_csv("../../../../datasets/CICBELLEXFDNS2021/Light/Attacks/stateless_features-light_audio.pcap.csv")
stateless_light_audio['Category'] = "Audio"
stateless_light_compressed = pd.read_csv("../../../../datasets/CICBELLEXFDNS2021/Light/Attacks/stateless_features-light_compressed.pcap.csv")
stateless_light_compressed['Category'] = "Compressed"
stateless_light_exe = pd.read_csv("../../../../datasets/CICBELLEXFDNS2021/Light/Attacks/stateless_features-light_exe.pcap.csv")
stateless_light_exe['Category'] = "Exe"
stateless_light_image = pd.read_csv("../../../../datasets/CICBELLEXFDNS2021/Light/Attacks/stateless_features-light_image.pcap.csv")
stateless_light_image['Category'] = "Image"
stateless_light_text = pd.read_csv("../../../../datasets/CICBELLEXFDNS2021/Light/Attacks/stateless_features-light_text.pcap.csv")
stateless_light_text['Category'] = "Text"
stateless_light_video = pd.read_csv("../../../../datasets/CICBELLEXFDNS2021/Light/Attacks/stateless_features-light_video.pcap.csv")
stateless_light_video['Category'] = "Video"

stateless_light_benign = '../../../../datasets/CICBELLEXFDNS2021/Light/Benign/'

# Use regex to get stateless benign data only
stateless_light_benign_list = [f"{stateless_light_benign}{f}" for f in listdir(stateless_light_benign) if isfile(join(stateless_light_benign, f)) and re.search("^stateful", f) == None]

stateless_light_benign_df = pd.concat(map(pd.read_csv, stateless_light_benign_list), ignore_index=True)
stateless_light_benign_df['Category'] = "Benign"
stateless_light_benign_df['Class'] = "Benign"

# %%
stateless_light_malicious = pd.concat(
    [
        stateless_light_audio,
        stateless_light_compressed,
        stateless_light_exe,
        stateless_light_image,
        stateless_light_text,
        stateless_light_video,
    ],
    axis=0,
    ignore_index=True
)

stateless_light_malicious['Class'] = 'Malicious'

# %%
stateless_light_data = pd.concat(
    [
        stateless_light_malicious,
        stateless_light_benign_df
    ],
    axis=0,
    ignore_index=True
)

stateless_light_data = stateless_light_data.sample(frac=1).reset_index(drop=True)

# %%
stateless_light_data
# Out:
#                          timestamp  FQDN_count  subdomain_length  upper  \
# 0       2020-11-22 01:51:24.202163          24                 7      0
# 1       2020-11-21 17:37:47.920613          14                 0      0
# 2       2020-11-21 14:50:29.327762          13                 0      0
# 3       2020-11-21 16:49:17.220265          27                10      0
# 4       2020-11-21 16:51:42.899483          25                 3      0
# ...                            ...         ...               ...    ...
# 102769  2020-11-21 22:48:26.576824          27                10      0
# 102770  2020-11-21 17:07:23.729758          24                 7      0
# 102771  2020-11-21 22:30:22.897682          27                10      0
# 102772  2020-11-21 15:49:48.634125          18                 3      0
# 102773  2020-11-21 15:56:13.189829          24                 7      0
#
#         lower  numeric   entropy  special  labels  labels_max  labels_average  \
# 0          10        8  2.054029        6       6           7        3.166667
# 1          13        0  2.789735        1       2           9        6.500000
# 2          11        0  2.406304        2       3           6        3.666667
# 3          10       11  2.570417        6       6           7        3.666667
# 4          22        0  3.766260        3       3          17        7.666667
# ...       ...      ...       ...      ...     ...         ...             ...
# 102769     10       11  2.767195        6       6           7        3.666667
# 102770     10        8  2.054029        6       6           7        3.166667
# 102771     10       11  2.570417        6       6           7        3.666667
# 102772     15        0  2.713274        3       3          10        5.333333
# 102773     10        8  2.054029        6       6           7        3.166667
#
#        longest_word                sld  len  subdomain    Category      Class
# 0                 4                224   11          1       Image  Malicious
# 1            upload          uploadhub   10          0      Benign     Benign
# 2               win             tamwin    7          0      Benign     Benign
# 3                 2                192   14          1      Benign     Benign
# 4             money  money-foradclicks   21          1      Benign     Benign
# ...             ...                ...  ...        ...         ...        ...
# 102769            2                192   14          1  Compressed  Malicious
# 102770            4                224   11          1      Benign     Benign
# 102771            2                192   14          1  Compressed  Malicious
# 102772        dream         dream-seed   14          1      Benign     Benign
# 102773            4                224   11          1      Benign     Benign
#
# [102774 rows x 17 columns]

# %% [markdown]
# # 2. Exploratory Data Analysis (EDA)

# %%
stateless_heavy_data.head()
# Out:
#                     timestamp  FQDN_count  subdomain_length  upper  lower  \
# 0  2020-11-23 17:46:36.262335           9                 0      0      8
# 1  2020-11-24 21:04:41.384559          24                 7      0     10
# 2  2020-11-24 23:42:35.267373          27                10      0     10
# 3  2020-11-24 12:03:20.655379          27                10      0     10
# 4  2020-11-24 13:11:56.514421          17                 0      0     16
#
#    numeric   entropy  special  labels  labels_max  labels_average  \
# 0        0  2.154135        1       2           5        4.000000
# 1        8  2.054029        6       6           7        3.166667
# 2       11  2.767195        6       6           7        3.666667
# 3       11  2.570417        6       6           7        3.666667
# 4        0  2.678258        1       2          13        8.000000
#
#   longest_word            sld  len  subdomain Category      Class
# 0          bod          bodis    6          0   Benign     Benign
# 1            4            224   11          1    Video  Malicious
# 2            2            192   14          1      Exe  Malicious
# 3            2            192   14          1     Text  Malicious
# 4        daily  madanyatdaily   14          0   Benign     Benign

# %%
stateless_light_data.columns
# Out:
# Index(['timestamp', 'FQDN_count', 'subdomain_length', 'upper', 'lower',
#        'numeric', 'entropy', 'special', 'labels', 'labels_max',
#        'labels_average', 'longest_word', 'sld', 'len', 'subdomain', 'Category',
#        'Class'],
#       dtype='object')

# %%
stateless_light_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102774 entries, 0 to 102773
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   timestamp         102774 non-null  object
#  1   FQDN_count        102774 non-null  int64
#  2   subdomain_length  102774 non-null  int64
#  3   upper             102774 non-null  int64
#  4   lower             102774 non-null  int64
#  5   numeric           102774 non-null  int64
#  6   entropy           102774 non-null  float64
#  7   special           102774 non-null  int64
#  8   labels            102774 non-null  int64
#  9   labels_max        102774 non-null  int64
#  10  labels_average    102774 non-null  float64
#  11  longest_word      102770 non-null  object
#  12  sld               102774 non-null  object
#  13  len               102774 non-null  int64
#  14  subdomain         102774 non-null  int64
#  15  Category          102774 non-null  object
#  16  Class             102774 non-null  object
# dtypes: float64(2), int64(10), object(5)
# memory usage: 13.3+ MB

# %% [markdown]
# Show unique DNS exfiltration categories and their respective counts

# %%
stateless_light_data['Category'].value_counts()
# Out:
# Category
# Benign        60091
# Audio         17618
# Compressed    10241
# Exe            6450
# Video          4371
# Text           3479
# Image           524
# Name: count, dtype: int64

# %% [markdown]
# Show unique DNS exfiltration classes and their respective counts

# %%
stateless_light_data['Class'].value_counts()
# Out:
# Class
# Benign       60091
# Malicious    42683
# Name: count, dtype: int64

# %% [markdown]
# Check for NaN values

# %%
stateless_light_data.isna().any()
# Out:
# timestamp           False
# FQDN_count          False
# subdomain_length    False
# upper               False
# lower               False
# numeric             False
# entropy             False
# special             False
# labels              False
# labels_max          False
# labels_average      False
# longest_word         True
# sld                 False
# len                 False
# subdomain           False
# Category            False
# Class               False
# dtype: bool

# %% [markdown]
# Show NaN value counts for each column

# %%
stateless_light_data.isna().sum()
# Out:
# timestamp           0
# FQDN_count          0
# subdomain_length    0
# upper               0
# lower               0
# numeric             0
# entropy             0
# special             0
# labels              0
# labels_max          0
# labels_average      0
# longest_word        4
# sld                 0
# len                 0
# subdomain           0
# Category            0
# Class               0
# dtype: int64

# %%
stateless_light_data[stateless_light_data['longest_word'].isna()]
# Out:
#                         timestamp  FQDN_count  subdomain_length  upper  lower  \
# 23277  2020-11-21 16:16:29.036661           9                 0      0      8
# 43749  2020-11-21 16:16:29.228023          13                 3      0     11
# 44661  2020-11-21 16:55:23.255911          10                 0      0      9
# 58740  2020-11-21 16:55:23.213426          10                 0      0      9
#
#        numeric   entropy  special  labels  labels_max  labels_average  \
# 23277        0  1.820802        1       2           5        4.000000
# 43749        0  2.067168        2       3           5        3.666667
# 44661        0  2.120590        1       2           6        4.500000
# 58740        0  2.120590        1       2           6        4.500000
#
#       longest_word     sld  len  subdomain Category   Class
# 23277          NaN   nanit    6          0   Benign  Benign
# 43749          NaN   nanit    9          1   Benign  Benign
# 44661          NaN  nullpk    7          0   Benign  Benign
# 58740          NaN  nullpk    7          0   Benign  Benign

# %%
stateless_light_data = stateless_light_data.dropna()

# %%
labels = stateless_light_data['Category'].unique()
values = stateless_light_data['Category'].value_counts()

plt.figure(figsize=(5,4))
plt.pie(values, labels=labels, labeldistance=1.15, wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, autopct='%1.1f%%')
plt.title("Category Distribution", size=16)
plt.show()

# %%
labels = stateless_light_data['Class'].unique()
values = stateless_light_data['Class'].value_counts()

plt.figure(figsize=(5,4))
plt.pie(values, labels=labels, labeldistance=1.15, wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' }, autopct='%1.1f%%')
plt.title("Class Distribution", size=16)
plt.show()

# %% [markdown]
# # 3. Data preparation
#
# 1. Separate features from labels
# 2. Remove timestamps to prevent ML overfitting
# 3. Use target encoding for categorical columns
# 4. Encode labels
# 5. (Optional) Normalize data using [StandardScaler](https://www.geeksforgeeks.org/machine-learning/what-is-standardization-in-machine-learning/)

# %% [markdown]
# ## 3.1. Separate features from labels

# %%
X_stateless_light_data = stateless_light_data.drop(['Class'], axis=1)
y_stateless_light_data = stateless_light_data['Class']

# %% [markdown]
# ## 3.2. Remove timestamps to prevent ML overfiting

# %%
X_stateless_light_data.drop(['timestamp', 'Category'], axis=1, inplace=True)

# %%
X_stateless_light_data.head()
# Out:
#    FQDN_count  subdomain_length  upper  lower  numeric   entropy  special  \
# 0          24                 7      0     10        8  2.054029        6
# 1          14                 0      0     13        0  2.789735        1
# 2          13                 0      0     11        0  2.406304        2
# 3          27                10      0     10       11  2.570417        6
# 4          25                 3      0     22        0  3.766260        3
#
#    labels  labels_max  labels_average longest_word                sld  len  \
# 0       6           7        3.166667            4                224   11
# 1       2           9        6.500000       upload          uploadhub   10
# 2       3           6        3.666667          win             tamwin    7
# 3       6           7        3.666667            2                192   14
# 4       3          17        7.666667        money  money-foradclicks   21
#
#    subdomain
# 0          1
# 1          0
# 2          0
# 3          1
# 4          1

# %% [markdown]
# ## 3.3. Target encoding categorical columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import TargetEncoder

# %% [markdown]
# Check unique value count in categorical columns in feature data

# %%
categorical_columns = X_stateless_light_data.select_dtypes(include='object').columns
for column in categorical_columns:
    print(f"Column: {column}, unique values: {len(stateless_light_data[column].unique())}")
# Out:
# Column: longest_word, unique values: 6223
# Column: sld, unique values: 11105

# %% [markdown]
# Target encode categorical columns

# %%
encoder = TargetEncoder(
    categories='auto',
    target_type='binary',  # Categorize between Benign and Malicious
    smooth='auto',
    cv=5,
    random_state=42
)

# %%
categorical_columns = X_stateless_light_data.select_dtypes(include='object').columns
categorical_columns
# Out:
# Index(['longest_word', 'sld'], dtype='object')

# %%
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X_stateless_light_data, y_stateless_light_data, test_size=0.2, random_state=42)

# %%
# %%time

X_train[categorical_columns] = encoder.fit_transform(X_train[categorical_columns], y_train)
# Out:
# CPU times: user 163 ms, sys: 2.08 ms, total: 165 ms
# Wall time: 167 ms

# %%
# %%time

X_test[categorical_columns] = encoder.transform(X_test[categorical_columns])
# Out:
# CPU times: user 51.2 ms, sys: 55 μs, total: 51.3 ms
# Wall time: 50.9 ms

# %% [markdown]
# ## 3.4. Encode labels

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)

# %%
X_train.shape, y_train.shape
# Out:
# ((82216, 14), (82216,))

# %%
X_test.shape, y_test.shape
# Out:
# ((20554, 14), (20554,))

# %% [markdown]
# ## 3.5. Normalize data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# # 4. Model training
#
# XGBoost will be trained and tested on heavy stateless data

# %% [markdown]
# ## 4.1. Training

# %%
# %%time

model = xgb.XGBClassifier()
model.fit(X_train, y_train)
# Out:
# CPU times: user 1.13 s, sys: 57.8 ms, total: 1.19 s
# Wall time: 228 ms
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ## 4.2. Testing

# %%
# %%time

y_pred = model.predict(X_test)
# Out:
# CPU times: user 109 ms, sys: 0 ns, total: 109 ms
# Wall time: 17.3 ms

# %%
from sklearn.metrics import accuracy_score, root_mean_squared_error, mean_squared_error, mean_absolute_error, precision_score, confusion_matrix, multilabel_confusion_matrix, classification_report, f1_score, precision_score, recall_score

# %%
results_dict = {}

accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
precision = precision_score(y_true=y_test, y_pred=y_pred, average="weighted")
f1 = f1_score(y_true=y_test, y_pred=y_pred, average="weighted")
recall = recall_score(y_true=y_test, y_pred=y_pred, average="weighted")
mae = mean_absolute_error(y_true=y_test,y_pred=y_pred)
mse = mean_squared_error(y_true=y_test,y_pred=y_pred) 
rmse = root_mean_squared_error(y_true=y_test,y_pred=y_pred)

results = [accuracy, precision, f1, recall, mae, mse, rmse]
results_dict["XGB_light_stateless"] = results

pd.DataFrame.from_dict(results_dict, orient="index", columns=["Accuracy", "Precision", "F1", "Recall", "MAE", "MSE", "RMSE"])
# Out:
#                      Accuracy  Precision       F1    Recall       MAE  \
# XGB_light_stateless  0.769583   0.851468  0.76638  0.769583  0.230417
#
#                           MSE      RMSE
# XGB_light_stateless  0.230417  0.480018

# %% [markdown]
# # 5. Hyperparameter tuning
#
# Hyperparameter tuning using optuna

# %%
pass

# %% [markdown]
# # 6. Save model

# %%
import pickle

# %%
dir = '../../../../models/CICBELLEXFDNS2021/light/stateless/'

with open(f'{dir}XGB_light_stateless.pkl', 'wb') as f:
    pickle.dump(model, f)
